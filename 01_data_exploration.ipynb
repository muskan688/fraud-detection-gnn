# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Load only 100,000 rows instead of full dataset
print("Loading transaction data (sample)...")
train_transaction = pd.read_csv('train_transaction.csv', nrows=100000)

print("Loading identity data...")
train_identity = pd.read_csv('train_identity.csv')

print("\n✅ Data loaded successfully!")
print(f"Transaction data shape: {train_transaction.shape}")
print(f"Identity data shape:    {train_identity.shape}")
